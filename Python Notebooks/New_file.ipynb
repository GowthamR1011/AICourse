# %% [markdown]
# <a href="https://colab.research.google.com/github/GowthamR1011/Deep-Learning/blob/main/Python%20Notebooks/New_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# What is this shit

# %%
# Lets check push

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.arange(0,10))

# %%
# !git clone https://github.com/GowthamR1011/Deep-Learning.git
# Out:
# Cloning into 'Deep-Learning'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 62 (delta 10), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (62/62), 131.52 KiB | 4.70 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
plt.plot(df['total_rooms'],df['median_income'])

# %%
df.to_csv('/content/Deep-Learning/Data Files/housing.csv')
